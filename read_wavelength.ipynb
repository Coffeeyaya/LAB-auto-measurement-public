# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("wavelength_power.csv")

# %%
df
# Out:
#     wavelength_arr  power_percentage_arr  power_arr
# 0       450.000000            117.310237        0.0
# 1       466.428571             89.692935        0.0
# 2       482.857143             69.602176        0.0
# 3       499.285714             54.986751        0.0
# 4       515.714286             44.354466        0.0
# 5       532.142857             36.619798        0.0
# 6       548.571429             30.993059        0.0
# 7       565.000000             26.899775        0.0
# 8       581.428571             23.922033        0.0
# 9       597.857143             21.755815        0.0
# 10      614.285714             20.179956        0.0
# 11      630.714286             19.033567        0.0
# 12      647.142857             18.199602        0.0
# 13      663.571429             17.592918        0.0
# 14      680.000000             17.151574        0.0
