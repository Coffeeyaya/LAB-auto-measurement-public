# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("wavelength_power.csv")

# %%
df
# Out:
#     wavelength_arr  power_percentage_arr  power_arr
# 0            400.0            282.861878        0.0
# 1            410.0            235.869392        0.0
# 2            420.0            197.151128        0.0
# 3            430.0            165.250198        0.0
# 4            440.0            138.966238        0.0
# 5            450.0            117.310237        0.0
# 6            460.0             99.467325        0.0
# 7            470.0             84.766112        0.0
# 8            480.0             72.653421        0.0
# 9            490.0             62.673477        0.0
# 10           500.0             54.450756        0.0
# 11           510.0             47.675854        0.0
# 12           520.0             42.093846        0.0
# 13           530.0             37.494692        0.0
# 14           540.0             33.705336        0.0
# 15           550.0             30.583193        0.0
# 16           560.0             28.010782        0.0
# ...
